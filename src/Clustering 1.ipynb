# %% [markdown]
# # Análisis de clustering para la identificación de perfiles financieros de las IPS en Colombia

# %% [markdown]
# ##### Objetivo : Aplicar tecnicas de mineria de datos para para identificar y analizar grupos de Instituciones Prestadoras de Servicios de Salud (IPS) en Colombia con comportamientos financieros y operativos similares, a partir de variables económicas, administrativas y de cobertura.

# %% [markdown]
# ## 1. Carga del Dataset y exploracion inicial

# %%
# importar librerias necesarias para carga de datas
import pandas as pd

# %%
# cargar y leer dataset
df = pd.read_csv("../Datas/ips_info_2023.csv")
df.tail() # 5530 datos
# Out:
#       NumeroIdentificacion                                    NombrePrestador  \
# 5525             901455999                                 METRISALUD IPS SAS
# 5526             900096797  CENTRO DE DERMATOLOGIA Y CIRUGIA DERMATOLOGICA...
# 5527             811038083                             FUNDACIÓN ARCA MUNDIAL
# 5528             900594892                                  VACUNARTE LJC SAS
# 5529             901444105  UNIDAD DE FISIOTERAPIA Y REHABILITACION INTEGR...
#
#      NaturalezaJuridica ESE DepartamentoPrestador  MunicipioCode  \
# 5525            Privada  NO            BOGOTÁ D.C          11001
# 5526            Privada  NO            BOGOTÁ D.C          11001
# 5527            Privada  NO             ANTIOQUIA           5001
# 5528            Privada  NO                  META          50001
# 5529            Privada  NO               CAQUETÁ          18001
#
#      MunicipioPrestador  CantMunicipios  CantSedes     ACTIVOS  RankActivos  \
# 5525             BOGOTÁ               1          1  1074666640         3387
# 5526             BOGOTÁ               1          1     1267599         5529
# 5527           MEDELLÍN               1          1     1460001         5528
# 5528      VILLAVICENCIO               1          1    20321000         5490
# 5529          FLORENCIA               1          1    19010000         5495
#
#         PASIVOS  PATRIMONIO  INGRESOS  RankIngresos    GASTOS  COSTOS  \
# 5525  117477812   957188828   1866585          5526  39721397       0
# 5526     250971     1016628   1777882          5527    882047  794089
# 5527     131556     1328445   1368381          5528   1274374       0
# 5528     450000    19871000   1000000          5529    950000  180000
# 5529      10000    19000000   1000000          5530    490000  500000
#
#       UTILIDADES  PERIODO MargenNeto%
# 5525   -37854812     2023    -2028,03
# 5526      101746     2023        5,72
# 5527       94007     2023        6,87
# 5528     -130000     2023         -13
# 5529       10000     2023           1

# %% [markdown]
# #### Analisis
# ##### Se identifica que dataset reune informacion financiera y operativa de las IPS en Colombia durante el periodo 2023, cada fila representando una institucion prestadora de servicios de salud

# %%
# imprimir las columnas y el tipo de varibles que tiene el dataset
print(df.info())
print(df.dtypes)
print(print(df.isnull().sum()))
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5530 entries, 0 to 5529
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   NumeroIdentificacion   5530 non-null   int64
#  1   NombrePrestador        5530 non-null   str
#  2   NaturalezaJuridica     5530 non-null   str
#  3   ESE                    5530 non-null   str
#  4   DepartamentoPrestador  5530 non-null   str
#  5   MunicipioCode          5530 non-null   int64
#  6   MunicipioPrestador     5530 non-null   str
#  7   CantMunicipios         5530 non-null   int64
#  8   CantSedes              5530 non-null   int64
#  9   ACTIVOS                5530 non-null   int64
#  10  RankActivos            5530 non-null   int64
#  11  PASIVOS                5530 non-null   int64
#  12  PATRIMONIO             5530 non-null   int64
#  13  INGRESOS               5530 non-null   int64
#  14  RankIngresos           5530 non-null   int64
#  15  GASTOS                 5530 non-null   int64
#  16  COSTOS                 5530 non-null   int64
#  17  UTILIDADES             5530 non-null   int64
#  18  PERIODO                5530 non-null   int64
#  19  MargenNeto%            5530 non-null   str
# dtypes: int64(14), str(6)
# memory usage: 1.2 MB
# None
# NumeroIdentificacion     int64
# NombrePrestador            str
# NaturalezaJuridica         str
# ESE                        str
# DepartamentoPrestador      str
# MunicipioCode            int64
# MunicipioPrestador         str
# CantMunicipios           int64
# CantSedes                int64
# ACTIVOS                  int64
# RankActivos              int64
# PASIVOS                  int64
# PATRIMONIO               int64
# INGRESOS                 int64
# RankIngresos             int64
# GASTOS                   int64
# COSTOS                   int64
# UTILIDADES               int64
# PERIODO                  int64
# MargenNeto%                str
# dtype: object
# NumeroIdentificacion     0
# NombrePrestador          0
# NaturalezaJuridica       0
# ESE                      0
# DepartamentoPrestador    0
# MunicipioCode            0
# MunicipioPrestador       0
# CantMunicipios           0
# CantSedes                0
# ACTIVOS                  0
# RankActivos              0
# PASIVOS                  0
# PATRIMONIO               0
# INGRESOS                 0
# RankIngresos             0
# GASTOS                   0
# COSTOS                   0
# UTILIDADES               0
# PERIODO                  0
# MargenNeto%              0
# dtype: int64
# None

# %% [markdown]
# #### Analisis
# ##### Se evidencia que el dataset contiene 5530 registros y varibales, ademas de no existir valores nulos dentro de la data. Para un mejor analisis se le tendra que hacer una conversion a la varibale MargenNeto%. ya que esta como texto, esta variable sera fundamental para el estudio.

# %% [markdown]
# ## 2. Tratamiento de variables

# %%
# Convertir a datos numericos
for col in df:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
#mostramos el contenido mde la columna, se puede ver que es tipo object
df["MargenNeto%"]
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 5525     NaN
# 5526     NaN
# 5527     NaN
# 5528   -13.0
# 5529     1.0
# Name: MargenNeto%, Length: 5530, dtype: float64

# %%
# rellenar los valores nulos
df = df.fillna(df.median())

# %%
# verificamos ahora si todas las variables 
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5530 entries, 0 to 5529
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   NumeroIdentificacion   5530 non-null   int64
#  1   NombrePrestador        0 non-null      float64
#  2   NaturalezaJuridica     0 non-null      float64
#  3   ESE                    0 non-null      float64
#  4   DepartamentoPrestador  0 non-null      float64
#  5   MunicipioCode          5530 non-null   int64
#  6   MunicipioPrestador     0 non-null      float64
#  7   CantMunicipios         5530 non-null   int64
#  8   CantSedes              5530 non-null   int64
#  9   ACTIVOS                5530 non-null   int64
#  10  RankActivos            5530 non-null   int64
#  11  PASIVOS                5530 non-null   int64
#  12  PATRIMONIO             5530 non-null   int64
#  13  INGRESOS               5530 non-null   int64
#  14  RankIngresos           5530 non-null   int64
#  15  GASTOS                 5530 non-null   int64
#  16  COSTOS                 5530 non-null   int64
#  17  UTILIDADES             5530 non-null   int64
#  18  PERIODO                5530 non-null   int64
#  19  MargenNeto%            5530 non-null   float64
# dtypes: float64(6), int64(14)
# memory usage: 864.2 KB
# None

# %% [markdown]
# ## 3. Eleccion de varibales para el clustering

# %%
# se eligen las variables que se van a utilizar para el clustering
variables_cluster = [
    # variables operativas
    'CantMunicipios',
    'CantSedes',
    # variables financieras
    'ACTIVOS',
    'PATRIMONIO',
    'INGRESOS',
    'UTILIDADES',
    # indicador de rentabilidad
    'MargenNeto%'
]

X = df[variables_cluster]
# Verificando que no existan valores nulos 
print(X.isnull().sum())
# Out:
# CantMunicipios    0
# CantSedes         0
# ACTIVOS           0
# PATRIMONIO        0
# INGRESOS          0
# UTILIDADES        0
# MargenNeto%       0
# dtype: int64

# %% [markdown]
# #### Analisis
# ##### Se seleccionaron estas variables unicamente numericas para poder relacionar el desempeño financiero y operativo de las IPS

# %%
# vemos que los valores son muy extremos entre el minimo y el maximo de algunas columnas
# por lo que debemos realizar una trasnformacion logaritmica
X.describe()
# Out:
#        CantMunicipios    CantSedes       ACTIVOS    PATRIMONIO      INGRESOS  \
# count     5530.000000  5530.000000  5.530000e+03  5.530000e+03  5.530000e+03
# mean         1.584448     2.563291  1.956834e+10  1.053856e+10  1.908597e+10
# std          2.415999     5.794958  8.083367e+10  4.748997e+10  7.833030e+10
# min          1.000000     1.000000  1.214444e+06 -4.079620e+11  1.000000e+06
# 25%          1.000000     1.000000  4.842593e+08  2.499762e+08  7.287338e+08
# 50%          1.000000     1.000000  1.981705e+09  1.060405e+09  2.427986e+09
# 75%          1.000000     2.000000  7.694398e+09  4.483227e+09  8.303602e+09
# max         40.000000   108.000000  1.725030e+12  1.027820e+12  1.974800e+12
#
#          UTILIDADES  MargenNeto%
# count  5.530000e+03  5530.000000
# mean   1.214785e+09     6.032188
# std    7.408894e+09     2.078504
# min   -1.292314e+11   -24.000000
# 25%    9.239574e+06     6.000000
# 50%    9.884252e+07     6.000000
# 75%    5.105489e+08     6.000000
# max    1.775983e+11    81.000000

# %% [markdown]
# ## 4. Estadistica descriptiva

# %%
import numpy as np

# %%
print ("Estadistica descriptiva de los variables escogidas: ")
X.describe()
# Out:
# Estadistica descriptiva de los variables escogidas:
#        CantMunicipios    CantSedes       ACTIVOS    PATRIMONIO      INGRESOS  \
# count     5530.000000  5530.000000  5.530000e+03  5.530000e+03  5.530000e+03
# mean         1.584448     2.563291  1.956834e+10  1.053856e+10  1.908597e+10
# std          2.415999     5.794958  8.083367e+10  4.748997e+10  7.833030e+10
# min          1.000000     1.000000  1.214444e+06 -4.079620e+11  1.000000e+06
# 25%          1.000000     1.000000  4.842593e+08  2.499762e+08  7.287338e+08
# 50%          1.000000     1.000000  1.981705e+09  1.060405e+09  2.427986e+09
# 75%          1.000000     2.000000  7.694398e+09  4.483227e+09  8.303602e+09
# max         40.000000   108.000000  1.725030e+12  1.027820e+12  1.974800e+12
#
#          UTILIDADES  MargenNeto%
# count  5.530000e+03  5530.000000
# mean   1.214785e+09     6.032188
# std    7.408894e+09     2.078504
# min   -1.292314e+11   -24.000000
# 25%    9.239574e+06     6.000000
# 50%    9.884252e+07     6.000000
# 75%    5.105489e+08     6.000000
# max    1.775983e+11    81.000000

# %%
# histograma de valores originales
import matplotlib.pyplot as plt

# visualizacion de la normalizacion con historigrama
plt.figure(figsize=(18,12))
plt.suptitle("Datos originales")
#  colores por variables
colores = {
    # variables operativas
    'CantMunicipios': 'skyblue',
    'CantSedes': 'skyblue',
    
    # variables financieras
    'ACTIVOS': 'lightcoral',
    'PASIVOS': 'lightcoral',
    'PATRIMONIO': 'lightcoral',
    'INGRESOS': 'lightcoral',
    'GASTOS': 'lightcoral',
    'COSTOS': 'lightcoral',
    
    'UTILIDADES': 'lightgreen',
    
    'MargenNeto%': 'gold'
}
# crear histogramas
for i, columna in enumerate(X.columns, 1):
    plt.subplot(4,3,i)
    plt.hist(
        X[columna],
        bins=30,
        color=colores[columna],
        edgecolor='black'
    )
    plt.title(columna)
    plt.xlabel('')
    plt.ylabel('Frecuencia')
    
plt.tight_layout()
plt.show()

# %%
# vemos que hay valores son muy extremos entre el minimo y el maximo de algunas columnas
# por lo que debemos realizar una trasnformacion logaritmica

# a que variables aplicar logaritmo (solo valores positivos)
var_log = [
    'ACTIVOS',
    'INGRESOS',
]

X_log = X.copy()
X_log[var_log] = np.log1p(X_log[var_log])
X_log.describe()
# Out:
#        CantMunicipios    CantSedes      ACTIVOS    PATRIMONIO     INGRESOS  \
# count     5530.000000  5530.000000  5530.000000  5.530000e+03  5530.000000
# mean         1.584448     2.563291    21.467937  1.053856e+10    21.676623
# std          2.415999     5.794958     2.064480  4.748997e+10     1.907824
# min          1.000000     1.000000    14.009798 -4.079620e+11    13.815512
# 25%          1.000000     1.000000    19.998131  2.499762e+08    20.406819
# 50%          1.000000     1.000000    21.407223  1.060405e+09    21.610328
# 75%          1.000000     2.000000    22.763758  4.483227e+09    22.839955
# max         40.000000   108.000000    28.176266  1.027820e+12    28.311488
#
#          UTILIDADES  MargenNeto%
# count  5.530000e+03  5530.000000
# mean   1.214785e+09     6.032188
# std    7.408894e+09     2.078504
# min   -1.292314e+11   -24.000000
# 25%    9.239574e+06     6.000000
# 50%    9.884252e+07     6.000000
# 75%    5.105489e+08     6.000000
# max    1.775983e+11    81.000000

# %% [markdown]
# #### Analisis
# ##### Aqui se evidencia una gran heterogeniedad entre las IPS, lo que indica diferencias importantes en el tamaño, cobertura y capacidad economica de las mismas

# %% [markdown]
# ## 5. Visualizacion de los datos

# %%
# importamos las librerias que necesitamos para dicha visualizacion 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_log = pd.DataFrame(X_log, columns=variables_cluster)
#Histograma con variables normalizadas
plt.figure(figsize=(18,15))
#  colores por variable
colores = {
    # variables operativas
    'CantMunicipios': 'skyblue',
    'CantSedes': 'skyblue',
    
    # variables financieras
    'ACTIVOS': 'lightcoral',
    'PASIVOS': 'lightcoral',
    'PATRIMONIO': 'lightcoral',
    'INGRESOS': 'lightcoral',
    'GASTOS': 'lightcoral',
    'COSTOS': 'lightcoral',
    
    'UTILIDADES': 'lightgreen',
    
    'MargenNeto%': 'gold'
}
# crear histogramas
for i, columna in enumerate(X_log.columns, 1):
    plt.subplot(4,3,i)
    plt.hist(
        X_log[columna],
        bins=30,
        color=colores[columna],
        edgecolor='black'
    )
    plt.title(columna)
    plt.xlabel('')
    plt.ylabel('Frecuencia')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Analisis
# ##### Los histogramas de las varibales dejan ver que la mayoria de varibales estan sesgadas hacia la parte derecha, indicando que muchas ips tiene desigualdad financiera, una gran cobertura regional y que muchas poseen rentabilidades pequeñas o ganancias y perdidas significativas.

# %%
# Boxplots
plt.figure(figsize=(18,12))
for i, columna in enumerate(X_log.columns, 1):
    plt.subplot(4,3,i)
    sns.boxplot(
        y=X_log[columna]
    )
    plt.title(columna)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Analisis
# ##### se evidencian muchos valores atipicos, indicando que existen ips significativamente mas grandes que el resto, con niveles financieros y operativos mayores.

# %%
# Matriz de correlacion 
correlacion = X_log.corr()
plt.figure(figsize=(12,8))
sns.heatmap(
    correlacion,
    annot=True,
    cmap='coolwarm',
    fmt='.2f'
)

plt.title('Matriz de correlacion')

# Mostrar
plt.show()

# %% [markdown]
# #### Analisis
# ##### Aqui se presentan varias correlaciones fuertes asociadas al tamaño y a la capacidad operativa de las ips, afirmando que las instituciones con mayores activos tienden a presentar mayores ingresos, costos y niveles de operacion, sin embargo, se evidencia tambien que el margen neto tiene correlacioens bajas, sugiriendo que depronto depende de factores distintos al tamaño.

# %% [markdown]
# ## 6. Metodo del codo

# %% [markdown]
# ##### Este metodo es utilziado para entender y poder determinar cual es el numero de grupos que mejor se puede adaptar a nuestro modelo de analisis

# %%
# importamos librerias necesarias para la creacion de un modelo (cluster)
from sklearn.cluster import KMeans

# %%
# lista para guardar valores de error por cada cluster
inercia = []

# para probar los diferentes n_cluster o grupos (1, 2...10 cluesters)
for k in range(1,11):
    # modelo KMeans dandole  que elija entre 10 la mejor opcion
    modelo = KMeans(
        n_clusters=k, # k como numero de grupos
        random_state=42, # un valor para que sea reproducible 
        n_init=10 # que elija entre 10 opciones la mejor (estabilidad)
    )
    # entrena el modelo, analizando datos, centroides y agrupando por ips
    modelo.fit(X_log)
    # guardar inercia, que tan cerca estan los datos del centro n_init
    inercia.append(modelo.inertia_) # mayor inercia = cluster mas compactos

# Grafico
plt.figure(figsize=(8,5))

plt.plot(range(1,11), inercia, marker='o')

plt.xlabel('Número de clusters')
plt.ylabel('Inercia')
plt.title('Método del Codo')

plt.grid()

plt.show()

# %% [markdown]
# ### Analisis

# %% [markdown]
# ##### El metodo del codo fue utilizado para ver graficamente los numeros de cluster mas optimo, calculando la inercia para grupos entre 1 y 10. La inercia es la suma de las distancias de cada entrenamiento con respecto a su centroide. Segun el grafico el numero mas optimo donde esta inercia se empieza a estabilizar es 2 y 3, como se ve en forma de "codo".

# %% [markdown]
# ## 7. Clustering

# %%
# 
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
kmeans.fit(X_log)

# agregar columna de cluster a las datas
X_log['cluster'] = kmeans.labels_
df['cluster'] = kmeans.labels_

X_log = pd.DataFrame(
    X_log,
    columns=variables_cluster
)

# Cantidad de IPS por cluster
print(df['cluster'].value_counts())
# Out:
# cluster
# 0    5410
# 1     100
# 2      20
# Name: count, dtype: int64

# %%
# Promedios por cluster
df.groupby('cluster')[variables_cluster].mean()
# Out:
#          CantMunicipios  CantSedes       ACTIVOS    PATRIMONIO      INGRESOS  \
# cluster
# 0              1.513494   2.330869  1.070455e+10  5.051603e+09  1.155364e+10
# 1              5.160000  13.390000  3.298070e+11  1.904132e+11  3.038036e+11
# 2              2.900000  11.300000  8.660304e+11  5.953859e+11  6.329934e+11
#
#            UTILIDADES  MargenNeto%
# cluster
# 0        6.772491e+08     6.026063
# 1        2.087011e+10     6.370000
# 2        4.834155e+10     6.000000

# %% [markdown]
# ## 8. Visualizacion y analisis de clusterings

# %% [markdown]
# ### 1. cluster por cobertura geografica (sedes y municipios donde estan)

# %%
# improtar libreria para mejor visualizacion y analisis de graficas
from matplotlib.pyplot import scatter

# %%
plt.figure(figsize=(10,6))

scatter = plt.scatter(
    df['CantMunicipios'],
    df['CantSedes'],
    c=df['cluster'],
    s=60
)

plt.xlabel('Cantidad de Municipios')
plt.ylabel('Cantidad de Sedes')
plt.title('Clusters según cobertura y sedes')
# clasificacion de cada cluster
legend1 = plt.legend(
    *scatter.legend_elements(),
    title='Clusters'
)

plt.gca().add_artist(legend1)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Interpretacion

# %% [markdown]
# ##### el eje 'x' es la cantidad de municipios donde estan y el eje 'y' la canidad de sedes que tiene operando.Cluster 0 -> ubicado mayormente en la parte inferior izquierda nos dice que la mayoria de las IPS cuentan con pocas sedes, operacion mas local y una baja cobertura municipal, lo que indica que las pequeñas o regionales IPS tienen una limitada capacidad de expancion.
#
# Cluster 1 -> muy disperso pero contando con IPS hacia la derecha y arriba lo que indica una alta cantidad de sedes operando en varios municipios, probablemente posean una mayor capacidad de antencion y recursos operativos.
#
# Cluster 2 -> estas son muy pocas se encuentra mas disperso pero en zonas mas intermedias, indicando una cobertura regional con un crecimiento operativo moderado y una capacidad administrativa mas estable

# %% [markdown]
# ### 2. Cluster financiero (activos e ingresos)

# %%
plt.figure(figsize=(10,6))

scatter = plt.scatter(
    df['ACTIVOS'],
    df['INGRESOS'],
    c=df['cluster'],
    s=60
)

plt.xlabel('ACTIVOS')
plt.ylabel('INGRESOS')
plt.title('Clusters según activos e ingresos')
# clasificacion de cada cluster
legend1 = plt.legend(
    *scatter.legend_elements(),
    title='Clusters'
)
plt.gca().add_artist(legend1)

plt.grid(True)

plt.show()

# %% [markdown]
# ### Interpretacion

# %% [markdown]
# #### Se observa una tendencia positiva tanto en ingresos y activos, es decir, a medida que aumentan los activos y tambien aumentan los ingresos, teniendo sentido ya que las IPS mas grandes pueden atender mas pacientes y ofrecer mas servicios

# %% [markdown]
# CLUSTER 0 MORADO -> este cluster represetan IPS pequeñas o medianas con una limitada y menor volumne de opracion, presentando gran despersion, indicando que algunas IPS poseen activos relativamente bajos pero generan ingresos moderados, mientras otras no logran transformar sus activos en ingresos significativos
#
# CLUSTER 1 VERDE -> representa IPS mas consolidadas, con mayor capacidad operativa, indicando que no todas las IPS convierten sus activos en ingresos con la misma eficiencia
#
# CLUSTER 3 AMARILLO -> Representan a las IPS altamente desarrolladas y financieramente fuertes, teniendo gran capacidad de generacion de ingreso y uso eficiente de activos.

# %% [markdown]
# ### 3. Rentabilidad de la IPS (ingresos y utilidad)

# %%
plt.figure(figsize=(10,6))

scatter = plt.scatter(
    df['INGRESOS'],
    df['UTILIDADES'],
    c=df['cluster'],
    s=60
)

plt.xlabel('INGRESOS')
plt.ylabel('UTILIDADES')
plt.title('Clusters según ingresos y utilidades')

# clasificacion de cada cluster
legend1 = plt.legend(
    *scatter.legend_elements(),
    title='Clusters'
)
plt.gca().add_artist(legend1)

plt.grid(True)

plt.show()

# %% [markdown]
# ### Interpretacion

# %% [markdown]
# #### Esta grafica indica que existe una tendencia positiva con utilidades en cuanto a ingresos, sifnificando que mayores ingresos no garantizan mayores ganancias porque influyen factores como costo, gastos adminsitrativos, etc.

# %% [markdown]
# CLUSTER 1 -> Se observa que muchas IPS tiene utilidades cercanas a 0 y otras presentan utilidades negativas, lo que deja en evidencia baja capaidad financiera y inestabilidad, afirmando que muchas IPS gastan mas de lo que generan, costos elevados y problemas de sostenibilidad
#
# CLUSTER 2 -> Deja ver que algunas IPS tiene ingresos medios y altos,, representando IPS mucho mas organizadas, mejor estrcutura adminisrativa y operaciones mas eficientes.
#
# CLUSTER 3 -> Representa aquellas IPS que son la mas rentables del sistema, siendo pocas pero concentran gran parte del rendimiento económico

# %% [markdown]
# ### 4. Margen neto y su patrimonio

# %%
plt.figure(figsize=(10,6))

scatter = plt.scatter(
    df['PATRIMONIO'],
    df['MargenNeto%'],
    c=df['cluster'],
    s=60
)

plt.xlabel('PATRIMONIO')
plt.ylabel('Margen Neto %')
plt.title('Clusters según patrimonio y rentabilidad')
# clasificacion de cada cluster
legend1 = plt.legend(
    *scatter.legend_elements(),
    title='Clusters'
)
plt.gca().add_artist(legend1)

plt.grid(True)

plt.show()

# %% [markdown]
# ### Interpretacion

# %% [markdown]
# ##### A diferencia de otras graficas, en esta no se observa una relación lineal fuerte entre patrimonio y margen neto, es decir, tener mayor patrimonio no garantiza automaicamente mayor rentabilidad

# %% [markdown]
# CLUSTER 1- > Este cluster muestra gran inestabilidad financiera, teniendo baja capacidad patrimonial
#
# CLUSTER 2 -> Evidnecia IPS con estrcuturas mas consolidades, financieramente mas equilibradas.
#
# CLUSTER 3 -> Evidencia tambien IPS con alta solidez fiannciera y estabilidad economica.

# %% [markdown]
# ### Esta parte nos muestra muchas mas relaciones entre variables por cluster (parecido al mapa de calor)

# %%
sns.pairplot(
    df[
        [
            'CantMunicipios',
            'CantSedes',
            'INGRESOS',
            'UTILIDADES',
            'MargenNeto%',
            'cluster'
        ]
    ],
    hue='cluster',
    palette='viridis'
)

plt.show()

# %% [markdown]
# ### Interpretacion

# %% [markdown]
# ##### Esta grafico por pares nuestra grupos diferenciados, alta concentraciosn de IPS pequeñas y relaciones positivas entre variables operativas y financieras. Por ejemplo, las IPS con mas sedes tienden tambien a operar en más municipios y asi con los demas graficos

# %%
print("\nINTERPRETACIÓN")

for cluster in sorted(df['cluster'].unique()):

    cantidad = len(df[df['cluster'] == cluster])

    print(f"\nCluster {cluster}")
    print(f"Cantidad de IPS: {cantidad}")
# Out:
# INTERPRETACIÓN
#
# Cluster 0
# Cantidad de IPS: 5410
#
# Cluster 1
# Cantidad de IPS: 100
#
# Cluster 2
# Cantidad de IPS: 20

# %% [markdown]
# ### Interpretacion

# %% [markdown]
# #### Esta seccion representa la cantidad de IPS que fueron asignadas a cada cluster despues de aplicar el algoritmo de clustering
